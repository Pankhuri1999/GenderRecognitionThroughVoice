# %%
#Downloading all the libraries
import os
import keras
from keras.preprocessing import image
from keras.applications.imagenet_utils import decode_predictions, preprocess_input
from keras.models import Model
import tensorflow
import random
import numpy
from scipy.spatial import distance
import pandas as pd
import pandas as pd
import numpy as np
import os
import tqdm
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping
from sklearn.model_selection import train_test_split

# %%
df1 = pd.read_csv('https://github.com/x4nth055/gender-recognition-by-voice/blob/master/balanced-all.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-8-4293f61c54c6> in <cell line: 1>()
# ----> 1 pd.read_csv('https://github.com/x4nth055/gender-recognition-by-voice/blob/master/balanced-all.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
! wget -r -voxforge.tgz http://www.repository.voxforge1.org/downloads/Russian/Trunk/Audio/Original/48kHz_16bit/

# %%
# !wget http://storage.googleapis.com/us_audioset/youtube_corpus/v1/csv/class_labels_indices.csv
# Out:
# --2024-03-31 21:43:25--  http://storage.googleapis.com/us_audioset/youtube_corpus/v1/csv/class_labels_indices.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.212.207, 173.194.213.207, 173.194.215.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.212.207|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14675 (14K) [application/octet-stream]
# Saving to: ‘class_labels_indices.csv’
#
# class_labels_indice 100%[===================>]  14.33K  --.-KB/s    in 0s
#
# 2024-03-31 21:43:25 (125 MB/s) - ‘class_labels_indices.csv’ saved [14675/14675]

# %%
df2 = pd.read_csv('class_labels_indices.csv')

# %%
df2
# Out:
#      index         mid                   display_name
# 0        0    /m/09x0r                         Speech
# 1        1   /m/05zppz      Male speech, man speaking
# 2        2    /m/02zsn  Female speech, woman speaking
# 3        3    /m/0ytgt     Child speech, kid speaking
# 4        4   /m/01h8n0                   Conversation
# ..     ...         ...                            ...
# 522    522  /m/07p_0gm                      Throbbing
# 523    523   /m/01jwx6                      Vibration
# 524    524    /m/07c52                     Television
# 525    525    /m/06bz3                          Radio
# 526    526   /m/07hvw1                Field recording
#
# [527 rows x 3 columns]
